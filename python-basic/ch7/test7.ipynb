# %%
import pymysql

con = pymysql.connect(
    host='127.0.0.1',
    user='webuser',
    password='webuser',
    database='webdb',
    charset='utf8')
print('DB 연결 성공!')

cur = con.cursor()   # 커서 생성 (SQL 실행 통로)
# Out:
# DB 연결 성공!

# %%
# 1. 기존에 있던 book 테이블이 있다면 먼저 삭제
cur.execute("DROP TABLE IF EXISTS book")

# 2. 새로 테이블 생성
sql = """
CREATE TABLE book (
    id INT AUTO_INCREMENT PRIMARY KEY,
    title VARCHAR(200),
    pub VARCHAR(45),
    pages INT,
    author VARCHAR(100)
)
"""
cur.execute(sql)
print('기존 테이블 삭제 후 새로 생성 성공!')
# Out:
# 기존 테이블 삭제 후 새로 생성 성공!

# %%
sql = "INSERT INTO book (title, pub, pages, author) VALUES (%s, %s, %s, %s)"
cur.execute(sql, ('머신러닝 입문', '길볏', 320, '박민수'))
con.commit()   # ← 없으면 저장 안 됨!
print('1개 행 추가됨')
# Out:
# 1개 행 추가됨

# %%
cur.execute('SELECT * FROM book')
rows = cur.fetchall()        # 모든 행
for row in rows:
    print(row)
# (1, '파이썬 기본서', '한빛미디어', 300, '김철수')

row = cur.fetchone()         # 한 행만
rows2 = cur.fetchmany(2)     # n개만 (페이지네이션)
# Out:
# (1, '머신러닝 입문', '길볏', 320, '박민수')

# %%
# 수정
cur.execute('UPDATE book SET pages = %s WHERE id = %s', (350, 1))
con.commit()

# 삭제
cur.execute('DELETE FROM book WHERE id = %s', (1,))
con.commit()

# %%
# DictCursor: 값을 이름으로 꺼내기
cur = con.cursor(pymysql.cursors.DictCursor)
cur.execute('SELECT * FROM book WHERE pages > %s ORDER BY pages DESC LIMIT 5', (200,))
for row in cur.fetchall():
    print(row['title'], row['pages'])

# Pandas와 연결: SQL 결과를 바로 DataFrame으로
import pandas as pd
df = pd.read_sql('SELECT * FROM book', con)
print(df.head())
# Out:
# Empty DataFrame
# Columns: [id, title, pub, pages, author]
# Index: []
# C:\Users\it\AppData\Local\Temp\ipykernel_17904\3467418527.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM book', con)

# %%
cur = con.cursor()
cur.execute("""
CREATE TABLE product (
    id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(100),
    price INT
)
""")
print('테이블 생성 완료')
# Out:
# 테이블 생성 완료

# %%
sql = "INSERT INTO product (name, price) VALUES (%s, %s)"
cur.execute(sql, ('노트북', 1200000))
con.commit()
print('삽입 완료')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 sql = "INSERT INTO product (name, price) VALUES (%s, %s)"
# ----> 2 cur.execute(sql, ('노트북', 1200000))
#       3 con.commit()
#       4 print('삽입 완료')
#
# NameError: name 'cur' is not defined

# %%
cur.execute('SELECT * FROM product WHERE price >= %s', (1000000,))
for row in cur.fetchall():
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cur.execute('SELECT * FROM product WHERE price >= %s', (1000000,))
#       2 for row in cur.fetchall():
#       3     print(row)
#
# NameError: name 'cur' is not defined
